# %%
import pandas as pd

import os
meu_diretorio = "/Users/andre/Desktop/Insper/2 SEMESTRE/Ciência dos Dados/PROJETO 1/2015"
os.chdir(meu_diretorio)

dados = pd.read_csv("DOM2015.csv")


tab = dados.loc[:,["UF","V0105","V0202","V0220","V0226","V02322","V02424","V02426","V4621"]]

tab.UF = dados.UF.astype('category')
tab.V0202 = dados.V0202.astype('category')
tab.V0220 = dados.V0220.astype('category')
tab.V0226 = dados.V0226.astype('category')
tab.V02322 = dados.V02322.astype('category')
tab.V02424 = dados.V02424.astype('category')
tab.V02426 = dados.V02426.astype('category')
tab.V4621 = dados.V4621.astype('category')

tab_nao_nulos = tab[pd.notnull(dados.V0202) & pd.notnull(dados.V0220) & pd.notnull(dados.V0226) & pd.notnull(dados.V02322) & pd.notnull(dados.V02424) & pd.notnull(dados.V02426) & pd.notnull(dados.V4621)]





tab_nao_nulos.columns = ["UF","N° de moradores","Tipo de domicílio","Telefone celular","TV em cores","Internet em casa", "Acesso por 3G","Acesso por banda larga", "Renda per capita"]

tab_nao_nulos.to_csv("Resumo.csv")
tab_nao_nulos
# Out:
#         UF  N° de moradores Tipo de domicílio Telefone celular TV em cores  \
# 2       11              1.0               4.0              2.0         4.0
# 3       11              6.0               2.0              2.0         2.0
# 5       11              1.0               2.0              4.0         2.0
# 8       11              5.0               2.0              2.0         2.0
# 10      11              3.0               2.0              2.0         2.0
# 11      11              1.0               2.0              2.0         2.0
# 13      11              2.0               4.0              2.0         2.0
# 15      11              3.0               4.0              2.0         2.0
# 17      11              4.0               2.0              2.0         2.0
# 18      11              5.0               2.0              2.0         2.0
# 19      11              2.0               2.0              2.0         2.0
# ...
