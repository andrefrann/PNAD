# %% [markdown]
# # Acesso à Internet e TV - André Annunziato - 2A
# ### A ideia do meu projeto é verificar o crescimento do uso da internet e tv nos estados do Nordeste baseado na renda e na quantidade de pessoas por residência, e verificar como elas se relacionam ao longo do tempo, além dos aparelhos (telefone celular, TV, computador) e redes (banda larga ou 3G) utilizados.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')


import os
pd.options.mode.chained_assignment = None
meu_diretorio = "/Users/andre/Desktop/Insper/2 SEMESTRE/Ciência dos Dados/PROJETO 1/2015"
os.chdir(meu_diretorio)

dados = pd.read_csv("DOM2015.csv")

tabela = dados.loc[:,["UF","V0105","V0202","V0220","V02322","V02323","V02325","V02326","V02424","V02426","V4621"]]

tabela = tabela[pd.notnull(dados.UF) & pd.notnull(dados.V0105) & pd.notnull(dados.V0202) & pd.notnull(dados.V0220) & pd.notnull(dados.V02322) & pd.notnull(dados.V02323) & pd.notnull(dados.V02325) & pd.notnull(dados.V02326) & pd.notnull(dados.V02424) & pd.notnull(dados.V02426) &  pd.notnull(dados.V4621)]

tabela = tabela[(dados.UF>=21) & (dados.UF<=29)]

tabela.UF = tabela.UF.astype('category')
tabela.V0105 = tabela.V0105.astype('int')
tabela.V0202 = tabela.V0202.astype('category')
tabela.V0220 = tabela.V0220.astype('category')
tabela.V02322 = tabela.V02322.astype('category')
tabela.V02323 = tabela.V02323.astype('category')
tabela.V02325 = tabela.V02325.astype('category')
tabela.V02326 = tabela.V02326.astype('category')
tabela.V02424 = tabela.V02424.astype('category')
tabela.V02426 = tabela.V02426.astype('category')
tabela.V4621 = tabela.V4621.astype('float')


tabela.UF.cat.categories = ("MA","PI","CE","RN","PB","PE","AL","SE","BA")
tabela.V0202.cat.categories = ("Casa","Apartamento","Cômodo")
tabela.V0220.cat.categories = ("Sim","Não")
tabela.V02322.cat.categories = ("Sim")
tabela.V02323.cat.categories = ("Sim","Não")
tabela.V02325.cat.categories = ("Sim","Não")
tabela.V02326.cat.categories = ("Sim","Não")
tabela.V02424.cat.categories = ("Sim","Não")
tabela.V02426.cat.categories = ("Sim","Não")


tabela.columns = ["UF","N° de moradores","Tipo de domicílio","Telefone móvel","Internet em casa","Acesso por PC","Acesso por tablet","Acesso por TV", "Acesso por 3G/4G","Acesso por banda larga", "Renda per capita"]

tabela.to_csv("Resumo.csv")
tabela
# Out:
# C:\Users\andre\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#        UF  N° de moradores Tipo de domicílio Telefone móvel Internet em casa  \
# 21444  MA                5              Casa            Sim              Sim
# 21448  MA                7              Casa            Sim              Sim
# 21451  MA                1              Casa            Sim              Sim
# 21452  MA                2              Casa            Sim              Sim
# 21455  MA                5              Casa            Sim              Sim
# 21456  MA                2              Casa            Sim              Sim
# 21466  MA                5              Casa            Sim              Sim
# 21467  MA                6              Casa            Sim              Sim
# 21484  MA                5              Casa            Sim              Sim
# 21485  MA                4              Casa            Sim              Sim
# 21489  MA                8              Casa            Sim              Sim
# 21491  MA                5              Casa            Sim              Sim
# 21497  MA                3              Casa            Sim              Sim
# 21498  MA                1              Casa            Sim              Sim
# 21514  MA                4              Casa            Sim              Sim
# 21515  MA                6              Casa            Sim              Sim
# 21516  MA                3              Casa            Sim              Sim
# 21517  MA                3              Casa            Sim              Sim
# 21518  MA                4              Casa            Sim              Sim
# 21519  MA                3              Casa            Sim              Sim
# 21522  MA                5              Casa            Sim              Sim
# 21524  MA                2              Casa            Sim              Sim
# 21525  MA                3              Casa            Sim              Sim
# 21526  MA                3              Casa            Sim              Sim
# 21528  MA                3              Casa            Sim              Sim
# 21529  MA                2              Casa            Sim              Sim
# 21530  MA                3              Casa            Sim              Sim
# 21532  MA                4              Casa            Sim              Sim
# 21533  MA                3              Casa            Sim              Sim
# 21534  MA                1              Casa            Sim              Sim
# ...    ..              ...               ...            ...              ...
# 64825  BA                2              Casa            Sim              Sim
# 64826  BA                4              Casa            Sim              Sim
# 64827  BA                4              Casa            Sim              Sim
# 64829  BA                5              Casa            Sim              Sim
# 64833  BA                3              Casa            Sim              Sim
# 64835  BA                3              Casa            Sim              Sim
# 64836  BA                4              Casa            Sim              Sim
# 64837  BA                3              Casa            Sim              Sim
# 64839  BA                2              Casa            Sim              Sim
# 64840  BA                3              Casa            Sim              Sim
# 64841  BA                2              Casa            Sim              Sim
# 64842  BA                2              Casa            Sim              Sim
# 64843  BA                4              Casa            Sim              Sim
# 64845  BA                2              Casa            Sim              Sim
# 64846  BA                1       Apartamento            Sim              Sim
# 64849  BA                1       Apartamento            Sim              Sim
# 64850  BA                1              Casa            Sim              Sim
# 64852  BA                2              Casa            Sim              Sim
# 64859  BA                4              Casa            Sim              Sim
# 64861  BA                3              Casa            Sim              Sim
# 64862  BA                4              Casa            Sim              Sim
# 64863  BA                3              Casa            Sim              Sim
# 64865  BA                4              Casa            Sim              Sim
# 64866  BA                2              Casa            Sim              Sim
# 64867  BA                5              Casa            Sim              Sim
# 64868  BA                4              Casa            Sim              Sim
# 64870  BA                3              Casa            Sim              Sim
# 64871  BA                3              Casa            Sim              Sim
# 64874  BA                5              Casa            Sim              Sim
# 64875  BA                3              Casa            Sim              Sim
#
#       Acesso por PC Acesso por tablet Acesso por TV Acesso por 3G/4G  \
# 21444           Não               Não           Não              Sim
# 21448           Não               Não           Não              Sim
# 21451           Não               Não           Não              Sim
# 21452           Sim               Não           Não              Não
# 21455           Não               Sim           Não              Sim
# 21456           Não               Não           Não              Sim
# 21466           Não               Não           Não              Sim
# 21467           Não               Não           Não              Sim
# 21484           Não               Não           Não              Sim
# 21485           Não               Não           Não              Sim
# 21489           Não               Não           Não              Sim
# 21491           Não               Não           Não              Sim
# 21497           Não               Não           Não              Sim
# 21498           Não               Não           Não              Sim
# 21514           Não               Não           Não              Sim
# 21515           Não               Não           Não              Sim
# 21516           Não               Não           Não              Sim
# 21517           Não               Não           Não              Sim
# 21518           Não               Não           Não              Sim
# 21519           Não               Não           Não              Sim
# 21522           Não               Não           Não              Sim
# 21524           Sim               Não           Não              Sim
# 21525           Não               Não           Não              Sim
# 21526           Não               Não           Não              Sim
# 21528           Não               Não           Não              Sim
# 21529           Não               Não           Não              Sim
# 21530           Não               Não           Não              Sim
# 21532           Não               Não           Não              Sim
# 21533           Não               Não           Não              Sim
# 21534           Não               Não           Não              Sim
# ...             ...               ...           ...              ...
# 64825           Sim               Não           Não              Sim
# 64826           Sim               Sim           Sim              Sim
# 64827           Sim               Sim           Não              Sim
# 64829           Não               Não           Não              Sim
# 64833           Sim               Não           Não              Sim
# 64835           Sim               Não           Não              Sim
# 64836           Sim               Não           Não              Sim
# 64837           Sim               Sim           Não              Sim
# 64839           Não               Não           Não              Sim
# 64840           Sim               Não           Não              Não
# 64841           Não               Não           Não              Sim
# 64842           Não               Não           Não              Sim
# 64843           Não               Não           Não              Sim
# 64845           Sim               Não           Não              Sim
# 64846           Sim               Não           Não              Sim
# 64849           Não               Não           Não              Sim
# 64850           Sim               Não           Não              Sim
# 64852           Não               Não           Não              Sim
# 64859           Sim               Sim           Sim              Sim
# 64861           Não               Não           Não              Sim
# 64862           Não               Sim           Não              Sim
# 64863           Sim               Não           Não              Sim
# 64865           Sim               Não           Não              Sim
# 64866           Não               Não           Não              Sim
# 64867           Sim               Sim           Não              Sim
# 64868           Sim               Sim           Não              Sim
# 64870           Sim               Não           Sim              Sim
# 64871           Sim               Sim           Não              Sim
# 64874           Sim               Não           Não              Sim
# 64875           Não               Não           Não              Sim
#
#       Acesso por banda larga  Renda per capita
# 21444                    Não             436.0
# 21448                    Não             187.0
# 21451                    Não            1900.0
# 21452                    Sim            2295.0
# 21455                    Não             680.0
# 21456                    Não             383.0
# 21466                    Não            1059.0
# 21467                    Não             453.0
# 21484                    Não             561.0
# 21485                    Não             702.0
# 21489                    Não             183.0
# 21491                    Não             522.0
# 21497                    Não             496.0
# 21498                    Não            2946.0
# 21514                    Não             483.0
# 21515                    Não             748.0
# 21516                    Não              38.0
# 21517                    Não            1046.0
# 21518                    Não             677.0
# 21519                    Não             418.0
# 21522                    Não             546.0
# 21524                    Não             131.0
# 21525                    Não             347.0
# 21526                    Não            1712.0
# 21528                    Não             400.0
# 21529                    Não             800.0
# 21530                    Não             415.0
# 21532                    Não             394.0
# 21533                    Não             304.0
# 21534                    Não             570.0
# ...                      ...               ...
# 64825                    Sim            2894.0
# 64826                    Sim            2625.0
# 64827                    Sim            1776.0
# 64829                    Não             300.0
# 64833                    Sim             593.0
# 64835                    Sim             993.0
# 64836                    Sim             219.0
# 64837                    Sim              60.0
# 64839                    Não             725.0
# 64840                    Sim             346.0
# 64841                    Não             250.0
# 64842                    Não             200.0
# 64843                    Não              25.0
# 64845                    Sim            1144.0
# 64846                    Sim            1576.0
# 64849                    Não             788.0
# 64850                    Sim            1000.0
# 64852                    Sim             794.0
# 64859                    Sim             572.0
# 64861                    Sim             200.0
# 64862                    Sim             945.0
# 64863                    Sim             447.0
# 64865                    Sim             600.0
# 64866                    Sim            1115.0
# 64867                    Sim             609.0
# 64868                    Sim             500.0
# 64870                    Sim            1033.0
# 64871                    Sim            1033.0
# 64874                    Não             680.0
# 64875                    Sim            1833.0
#
# [16044 rows x 11 columns]

# %%
pc = tabela["Acesso por PC"].value_counts()
#pc

# %% [markdown]
# ### Para efeito comparativo, serão mostrados alguns gráficos de acesso a Internet através de diferentes aparelhos:

# %%
pc.plot(kind='bar', color=('red', 'blue'), legend=False)
plt.title("Acesso à Internet por PC")

# %%
tablet = tabela["Acesso por tablet"].value_counts()
tablet.plot(kind='pie')
plt.title("Acesso à Internet via tablets")

# %%
tv = tabela["Acesso por TV"].value_counts()
tv.plot(kind='pie')
plt.title("Acesso à Internet via TV")

# %% [markdown]
# ### Para complementar os gráficos acima, a seguir há um gráfico de renda per capita. Como estamos tratando do Nordeste, é interessante relacionar a renda média - que é relativamente baixa - com os acessos mostrados acima.

# %%
faixa = np.arange(0,5000,10)
renda = pd.cut(tabela["Renda per capita"],faixa)
#renda.value_counts()

# %%
plot = tabela["Renda per capita"].plot.hist(bins=faixa, normed = False,figsize=(10,6))
plt.title("Renda per capita")

# %% [markdown]
# ### Conclui-se que apesar da baixa renda, o acesso à internet por PC ainda é bastante comum. Entretanto, o acesso por tablets e TVs ainda se mostra pouco frequente, justificado por se tratar de algo menos acessível.

# %% [markdown]
# ### O gráfico abaixo, por sua vez, que também se relaciona com a renda, mostra o número de pessoas que utilizam a internet através de banda larga e/ou 3G/4G.

# %%
acesso = pd.crosstab(tabela["Acesso por 3G/4G"], tabela["Acesso por banda larga"])
#acesso

# %%
acesso.plot(kind='bar',color=('yellow','green'))
plt.title("Acesso por Banda Larga e/ou Redes celulares")

# %% [markdown]
# ### É possível observar o baixissimo número de pessoas que não possuem nenhuma das duas conexões. Portanto, conclui-se que a expectativa de muitas pessoas, que ainda veem o Nordeste como uma região extremamente pobre e sem nenhuma estrutura é, em parte, falha, já que como mostrado abaixo, o acesso à Internet é de 100% (das pessoas que responderam à pesquisa), e muitos ainda dispõem de mais de um tipo de aparelho ou meio de conexão.

# %%
tv = tabela["Internet em casa"].value_counts()
tv.plot(kind='pie')
plt.title("Acesso à Internet")

# %%
tabela = tabela[tabela["Renda per capita"]!=999999999999]

#tabela["Renda per capita"].describe()

# %%
faixa = np.arange(0,5000,10)
renda = pd.cut(tabela["Renda per capita"],faixa)
#renda.value_counts()
